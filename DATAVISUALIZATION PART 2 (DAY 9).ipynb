# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("tips.csv")
df.head(5)
# Out:
#    Total_bill   Tip     Sex Smoker  Day    Time  Size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.style.use("ggplot")
sns.displot(x=df["Total_bill"],kde=True)
# Out:
# C:\Users\AHMADU\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.regplot(x=df["Total_bill"],y=df["Tip"])
# Out:
# <Axes: xlabel='Total_bill', ylabel='Tip'>

# %%
sns.scatterplot(x=df["Total_bill"],y=df["Tip"])
# Out:
# <Axes: xlabel='Total_bill', ylabel='Tip'>

# %%
sns.countplot(x=df["Day"])  ## This is the distributio of categorical columns.
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %%
sns.countplot(x=df["Day"],hue=df["Sex"])
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %%
sns.barplot(x=df["Day"], y=df["Total_bill"]) ## the black lines indicates more sales
# Out:
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %%
sns.barplot(x=df["Day"], y=df["Total_bill"],estimator=max) ## the highest sale in each day(max)
# Out:
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %%
sns.barplot(x=df["Day"], y=df["Total_bill"],estimator=min) ## the lowest sale in each day(min)
# Out:
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %%
sns.barplot(x=df["Day"], y=df["Total_bill"],estimator=max, palette="copper_r")
# Out:
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %%
sns.violinplot(x=df["Day"], y=df["Total_bill"], estimator=max, palettes="#4287f5")
# Out:
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %%
sns.boxplot(x=df["Total_bill"])
# Out:
# <Axes: xlabel='Total_bill'>

# %%
df.columns
# Out:
# Index(['Total_bill', 'Tip', 'Sex', 'Smoker', 'Day', 'Time', 'Size'], dtype='object')

# %%
sns.boxplot(y=df["Total_bill"], x=df["Day"])
# Out:
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %%
df2= sns.load_dataset("flights")
df2.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
## show the distribution between the Tips of a particular day.
## show the trend or relationship between the Tips and TotaL_bill

# %%
sns.barplot(x=df["Day"],y=df["Tip"],estimator=max)
# Out:
# <Axes: xlabel='Day', ylabel='Tip'>

# %%
sns.scatterplot(x=df["Total_bill"],y=df["Tip"])
# Out:
# <Axes: xlabel='Total_bill', ylabel='Tip'>

# %%
sns.lineplot(x=df["Day"], y=df["Tip"],estimator=max)
# Out:
# <Axes: xlabel='Day', ylabel='Tip'>

# %%
sns.violinplot(x=df["Day"], y=df["Tip"],estimator=max)
# Out:
# <Axes: xlabel='Day', ylabel='Tip'>

# %%
sns.pairplot(df)
# Out:
# C:\Users\AHMADU\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(12,8))
ax=sns.barplot(x=df["Sex"],y=df["Total_bill"],data=df,palette="Blues",estimator=max)
for p in ax.patches:
    ax.annotate(f"{p.get_height()}",(p.get_x()+ p.get_width()/ 2.,p.get_height()),
                ha="center",va="baseline", fontsize=10, color="red",xytext= (0,5),
                textcoords="offset points")
plt.title("Day Distribution")
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df2=df[["Total_bill","Tip","Size"]]
corr=df2.corr()
corr
# Out:
#             Total_bill       Tip      Size
# Total_bill    1.000000  0.675734  0.598315
# Tip           0.675734  1.000000  0.489299
# Size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,fmt="0.2g")
# Out:
# <Axes: >
